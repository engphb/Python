# %% [markdown]
# <a href="https://colab.research.google.com/github/engphb/Python/blob/main/Calories_percentages_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Find the percentages of each calories from carbs, proteins and fats in 100g of different foods.
#
# *   Item da lista
# *   Item da lista
#
#
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np

# %%
A = np.array([[56,0,4.4,68],
             [1.2,104,52,9], 
             [1.8,135,99,0.9]])
print(A)
# Out:
# [[ 56.    0.    4.4  68. ]
#  [  1.2 104.   52.    9. ]
#  [  1.8 135.   99.    0.9]]

# %%
x = A.sum(axis=0)
x
# Out:
# array([ 59. , 239. , 155.4,  77.9])

# %%
percentage = 100*A/x.reshape(1,4) 
print(percentage)
# Out:
# [[94.91525424  0.          2.83140283 87.29139923]
#  [ 2.03389831 43.51464435 33.46203346 11.55327343]
#  [ 3.05084746 56.48535565 63.70656371  1.15532734]]
